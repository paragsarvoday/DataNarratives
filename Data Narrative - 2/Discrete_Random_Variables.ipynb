# %%
print("Hello world!")
# Out:
# Hello world!

# %%
x = int(input("What's your favourite number?"))
for i in range(x):
    print(f"Number that comes prior to your favourite number is {i}")
# Out:
# What's your favourite number?5
# Number that comes prior to your favourite number is 0
# Number that comes prior to your favourite number is 1
# Number that comes prior to your favourite number is 2
# Number that comes prior to your favourite number is 3
# Number that comes prior to your favourite number is 4

# %%
print("P")
# Out:
# P

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
q = np.random.randint(7,size=100)
plt.hist(q+0.5,bins=6)
plt.show()

# %% [markdown]
# Why is the number of 6's obtained quite high even when the number of trials is increased?

# %%
q = np.random.randint(7,size=100000000)
plt.hist(q+0.5,bins=6)
plt.show()

# %%
#Python code to generate a PMF and a CDF
import numpy as np
import matplotlib.pyplot as plt
p = np.array([0.25,0.5,0.25])
x = np.array([0,1,4])
F = np.cumsum(p)

plt.stem(x,p,use_line_collection=True); plt.show()
plt.step(x,F)
# Out:
# C:\Users\parag\AppData\Local\Temp\ipykernel_8480\1884039340.py:8: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x,p,use_line_collection=True); plt.show()

# %%
#Python code to generate 1000 Bernoulli random variables
import numpy as np
import matplotlib.pyplot as plt
p = 0.5
n = 1
X = np.random.binomial(n,p,size=1000)
plt.hist(X, bins='auto')
# Out:
# (array([493.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 507.]),
#  array([0.        , 0.09090909, 0.18181818, 0.27272727, 0.36363636,
#         0.45454545, 0.54545455, 0.63636364, 0.72727273, 0.81818182,
#         0.90909091, 1.        ]),
#  <BarContainer object of 11 artists>)
